# %% [markdown]
# <a href="https://colab.research.google.com/github/Kusuma-1309/Neural-Networks-and-Deep-Learning/blob/main/Expt_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================
# CREDIT CARD FRAUD DETECTION
# ============================

import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

# ----------------------------
# 1. UNZIP DATASET
# ----------------------------
# !unzip -o archive.csv.zip

# ----------------------------
# 2. LOAD TRAIN & TEST FILES
# ----------------------------
train_df = pd.read_csv("/content/credit_card_fraud_10k.csv", encoding="latin1")
test_df  = pd.read_csv("/content/credit_card_fraud_10k.csv", encoding="latin1")

# ----------------------------
# 3. COMBINE DATA
# ----------------------------
df = pd.concat([train_df, test_df], ignore_index=True)

# Keep only numeric columns
df = df.select_dtypes(include=[np.number])
df = df.fillna(0)

print("Dataset shape:", df.shape)
print(df['is_fraud'].value_counts())

# ----------------------------
# 4. FEATURES & LABEL
# ----------------------------
X = df.drop('is_fraud', axis=1)
y = df['is_fraud']

# ----------------------------
# 5. TRAIN-TEST SPLIT
# ----------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# ----------------------------
# 6. FEATURE SCALING
# ----------------------------
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ----------------------------
# 7. HANDLE CLASS IMBALANCE
# ----------------------------
neg, pos = np.bincount(y_train)
class_weight = {0: 1.0, 1: neg / max(pos, 1)}
print("Class Weights:", class_weight)

# ----------------------------
# 8. BUILD MODEL
# ----------------------------
model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# ----------------------------
# 9. COMPILE MODEL
# LOSS FUNCTION: Binary Crossentropy
# ----------------------------
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=[
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.AUC(name='auc')
    ]
)

# ----------------------------
# 10. TRAIN MODEL (SAVE HISTORY)
# ----------------------------
history = model.fit(
    X_train, y_train,
    epochs=25,
    batch_size=256,
    validation_split=0.2,
    class_weight=class_weight,
    verbose=1
)

# ----------------------------
# 11. PREDICT PROBABILITIES
# ----------------------------
y_prob = model.predict(X_test).ravel()

# ----------------------------
# 12. APPLY THRESHOLD
# ----------------------------
THRESHOLD = 0.2 # fraud-friendly threshold
y_pred = (y_prob >= THRESHOLD).astype(int)

# ----------------------------
# 13. CONFUSION MATRIX
# ----------------------------
cm = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:\n", cm)

# ----------------------------
# 14. CLASSIFICATION REPORT
# ----------------------------
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# ----------------------------
# 15. ROC CURVE
# ----------------------------
fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1], [0,1], '--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# ----------------------------
# 16. CONFUSION MATRIX PLOT
# ----------------------------
plt.figure(figsize=(4,4))
plt.imshow(cm, cmap='Blues')
plt.title("Confusion Matrix")
plt.xticks([0,1], ['Normal', 'Fraud'])
plt.yticks([0,1], ['Normal', 'Fraud'])

for i in range(2):
    for j in range(2):
        plt.text(j, i, cm[i, j], ha='center', va='center')

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ----------------------------
# 17. LOSS CURVE (TRAIN vs VALIDATION)
# ----------------------------
plt.figure(figsize=(6,4))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss Curve (Binary Cross-Entropy)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Archive:  archive.csv.zip
#   inflating: credit_card_fraud_10k.csv
# Dataset shape: (20000, 9)
# is_fraud
# 0    19698
# 1      302
# Name: count, dtype: int64
# Class Weights: {0: 1.0, 1: np.float64(65.11570247933884)}
# Epoch 1/25
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - auc: 0.8591 - loss: 1.0915 - precision: 0.0553 - recall: 0.7166 - val_auc: 0.9543 - val_loss: 0.5035 - val_precision: 0.0513 - val_recall: 0.9535
# Epoch 2/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9601 - loss: 0.7815 - precision: 0.0616 - recall: 0.9311 - val_auc: 0.9744 - val_loss: 0.3704 - val_precision: 0.0719 - val_recall: 0.9767
# Epoch 3/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9788 - loss: 0.5092 - precision: 0.0873 - recall: 0.9796 - val_auc: 0.9830 - val_loss: 0.2824 - val_precision: 0.0915 - val_recall: 0.9767
# Epoch 4/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9844 - loss: 0.4081 - precision: 0.1097 - recall: 0.9948 - val_auc: 0.9876 - val_loss: 0.2260 - val_precision: 0.1126 - val_recall: 1.0000
# Epoch 5/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9882 - loss: 0.3200 - precision: 0.1325 - recall: 0.9885 - val_auc: 0.9885 - val_loss: 0.1896 - val_precision: 0.1335 - val_recall: 1.0000
# Epoch 6/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9899 - loss: 0.2876 - precision: 0.1579 - recall: 0.9954 - val_auc: 0.9893 - val_loss: 0.1560 - val_precision: 0.1727 - val_recall: 1.0000
# Epoch 7/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9926 - loss: 0.2210 - precision: 0.1932 - recall: 0.9998 - val_auc: 0.9893 - val_loss: 0.1461 - val_precision: 0.1853 - val_recall: 1.0000
# Epoch 8/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9935 - loss: 0.2042 - precision: 0.2085 - recall: 0.9986 - val_auc: 0.9902 - val_loss: 0.1648 - val_precision: 0.1629 - val_recall: 1.0000
# Epoch 9/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9928 - loss: 0.1972 - precision: 0.1868 - recall: 0.9997 - val_auc: 0.9901 - val_loss: 0.1314 - val_precision: 0.2048 - val_recall: 1.0000
# Epoch 10/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9946 - loss: 0.1714 - precision: 0.2215 - recall: 0.9993 - val_auc: 0.9905 - val_loss: 0.1213 - val_precision: 0.2081 - val_recall: 0.9535
# Epoch 11/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9958 - loss: 0.1561 - precision: 0.2312 - recall: 0.9974 - val_auc: 0.9906 - val_loss: 0.1267 - val_precision: 0.2050 - val_recall: 0.9535
# Epoch 12/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9957 - loss: 0.1556 - precision: 0.2617 - recall: 0.9975 - val_auc: 0.9906 - val_loss: 0.1167 - val_precision: 0.2216 - val_recall: 0.9535
# Epoch 13/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9943 - loss: 0.1626 - precision: 0.2857 - recall: 0.9978 - val_auc: 0.9905 - val_loss: 0.1130 - val_precision: 0.2253 - val_recall: 0.9535
# Epoch 14/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9952 - loss: 0.1417 - precision: 0.2597 - recall: 0.9980 - val_auc: 0.9906 - val_loss: 0.1071 - val_precision: 0.2330 - val_recall: 0.9535
# Epoch 15/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9955 - loss: 0.1365 - precision: 0.2966 - recall: 0.9938 - val_auc: 0.9906 - val_loss: 0.1158 - val_precision: 0.2228 - val_recall: 0.9535
# Epoch 16/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9941 - loss: 0.1470 - precision: 0.2762 - recall: 1.0000 - val_auc: 0.9906 - val_loss: 0.0907 - val_precision: 0.2579 - val_recall: 0.9535
# Epoch 17/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9951 - loss: 0.1386 - precision: 0.2882 - recall: 1.0000 - val_auc: 0.9905 - val_loss: 0.0827 - val_precision: 0.2733 - val_recall: 0.9535
# Epoch 18/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9954 - loss: 0.1345 - precision: 0.3397 - recall: 1.0000 - val_auc: 0.9908 - val_loss: 0.0944 - val_precision: 0.2562 - val_recall: 0.9535
# Epoch 19/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9955 - loss: 0.1251 - precision: 0.3238 - recall: 0.9987 - val_auc: 0.9908 - val_loss: 0.0963 - val_precision: 0.2595 - val_recall: 0.9535
# Epoch 20/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9967 - loss: 0.1099 - precision: 0.3384 - recall: 1.0000 - val_auc: 0.9909 - val_loss: 0.0947 - val_precision: 0.2595 - val_recall: 0.9535
# Epoch 21/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9961 - loss: 0.1147 - precision: 0.3358 - recall: 1.0000 - val_auc: 0.9909 - val_loss: 0.0870 - val_precision: 0.2645 - val_recall: 0.9535
# Epoch 22/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.9967 - loss: 0.1051 - precision: 0.3759 - recall: 1.0000 - val_auc: 0.9907 - val_loss: 0.0814 - val_precision: 0.2733 - val_recall: 0.9535
# Epoch 23/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.9957 - loss: 0.1106 - precision: 0.3266 - recall: 1.0000 - val_auc: 0.9910 - val_loss: 0.0873 - val_precision: 0.2680 - val_recall: 0.9535
# Epoch 24/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.9970 - loss: 0.0977 - precision: 0.3704 - recall: 1.0000 - val_auc: 0.9909 - val_loss: 0.0892 - val_precision: 0.2680 - val_recall: 0.9535
# Epoch 25/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.9774 - loss: 0.0967 - precision: 0.3443 - recall: 0.9804 - val_auc: 0.9909 - val_loss: 0.0789 - val_precision: 0.2971 - val_recall: 0.9535
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Confusion Matrix:
#  [[3751  189]
#  [   0   60]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98      3940
#            1       0.24      1.00      0.39        60
#
#     accuracy                           0.95      4000
#    macro avg       0.62      0.98      0.68      4000
# weighted avg       0.99      0.95      0.97      4000
