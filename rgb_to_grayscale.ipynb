# %% [markdown]
# <a href="https://colab.research.google.com/github/Kusuma-1309/Neural-Networks-and-Deep-Learning/blob/main/rgb_to_grayscale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
print(os.listdir("/content"))
# Out:
# ['.config', 'cnn_grayscale.jpg', 'Kusuma.jpg', '.ipynb_checkpoints', 'rgb_images', 'sample_data']

# %%
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image (RGB)
img = cv2.imread("/content/Kusuma.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (256, 256))
img = img / 255.0

# Add batch dimension
input_img = np.expand_dims(img, axis=0)

# CNN model
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(256, 256, 3)),
    tf.keras.layers.Conv2D(1, (1, 1), activation='linear')
])

# Predict grayscale
gray_pred = model.predict(input_img)

# Remove batch dimension
gray_img = gray_pred[0, :, :, 0]

# Display results
plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.title("Original RGB")
plt.imshow(img)
plt.axis("off")

plt.subplot(1,2,2)
plt.title("Grayscale (CNN)")
plt.imshow(gray_img, cmap="gray")
plt.axis("off")

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
